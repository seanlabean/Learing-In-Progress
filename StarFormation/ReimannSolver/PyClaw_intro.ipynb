# %% [markdown]
# This notebook demonstrates how to use the PyClaw software. Documentation is here: http://www.clawpack.org/pyclaw/basics.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from clawpack import pyclaw
from clawpack import riemann

# %% [markdown]
# First, we set up a PyClaw controller. This is the top-level control, and stores some of the overall simulation information.

# %%
claw = pyclaw.Controller()
claw.tfinal = 1.0
claw.keep_copy = True       # Keep solution data in memory for plotting
claw.output_format = None   # Don't write solution data to file
claw.num_output_times = 50  # Write 50 output frames

# %% [markdown]
# We must specify to PyClaw a Riemann solver, as well as an algorithm (solver). See http://www.clawpack.org/wp_algorithms.html for more details. For this example, we will use the 1D acoustics Riemann solver.

# %%
riemann_solver = riemann.acoustics_1D
claw.solver = pyclaw.ClawSolver1D(riemann_solver)

# %% [markdown]
# We must also specify the boundary conditions. Here we use periodic. Additional options include extrap, wall (reflecting), or user (for user-specified boundaries). See http://www.clawpack.org/bc.html.
#
# Other items that can be specified to the solver can be found here: http://www.clawpack.org/setrun.html

# %%
claw.solver.all_bcs = pyclaw.BC.periodic

# %% [markdown]
# Now we define the domain, running from 0 to 1, with 100 cells.

# %%
domain = pyclaw.Domain( (0.,), (1.,), (100,))

# %% [markdown]
# The "solution" object will hold the values of the solution. It needs to know the number of equations being solved, as well as the domain. In this case, the number of equations is a property of the solver (for the 1D acoustic solver, 2).

# %%
claw.solution = pyclaw.Solution(claw.solver.num_eqn,domain)

# %% [markdown]
# At this point, we are ready to specify the initial conditions. The variables are stored in the solution.q array. For the 1d acoustic solver, q[0] is pressure, and q[1] is density.

# %%
x=domain.grid.x.centers
bet=100; gam=5; x0=0.75
claw.solution.q[0,:] = np.exp(-bet * (x-x0)**2) * np.cos(gam * (x - x0))
claw.solution.q[1,:] = 0.

plt.plot(x, claw.solution.q[0,:],'-o')

# %% [markdown]
# The acoustics equations above have some coefficients – namely, the bulk modulus K and density ρ – that must be defined. Furthermore, checking the code for the Riemann solver we’ve chosen reveals that it expects us to provide values for the impedance Z and sound speed c. These values are stored in a Python dictionary called problem_data that is a member of the State.

# %%
density = 1.0
bulk_modulus = 1.0
impedance = np.sqrt(density*bulk_modulus)
sound_speed = np.sqrt(density/bulk_modulus)

claw.solution.state.problem_data = {
                              'rho' : density,
                              'bulk': bulk_modulus,
                              'zz'  : np.sqrt(density*bulk_modulus),
                              'cc'  : np.sqrt(bulk_modulus/density)
                              }

# %% [markdown]
# Okay, setup complete. Now we can run!

# %%
status = claw.run()
# Out:
# 2019-06-28 15:10:01,681 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-06-28 15:10:01,685 INFO CLAW: Solution 1 computed for time t=0.020000
# 2019-06-28 15:10:01,690 INFO CLAW: Solution 2 computed for time t=0.040000
# 2019-06-28 15:10:01,694 INFO CLAW: Solution 3 computed for time t=0.060000
# 2019-06-28 15:10:01,699 INFO CLAW: Solution 4 computed for time t=0.080000
# 2019-06-28 15:10:01,703 INFO CLAW: Solution 5 computed for time t=0.100000
# 2019-06-28 15:10:01,709 INFO CLAW: Solution 6 computed for time t=0.120000
# 2019-06-28 15:10:01,713 INFO CLAW: Solution 7 computed for time t=0.140000
# 2019-06-28 15:10:01,717 INFO CLAW: Solution 8 computed for time t=0.160000
# 2019-06-28 15:10:01,721 INFO CLAW: Solution 9 computed for time t=0.180000
# 2019-06-28 15:10:01,725 INFO CLAW: Solution 10 computed for time t=0.200000
# 2019-06-28 15:10:01,730 INFO CLAW: Solution 11 computed for time t=0.220000
# 2019-06-28 15:10:01,735 INFO CLAW: Solution 12 computed for time t=0.240000
# 2019-06-28 15:10:01,739 INFO CLAW: Solution 13 computed for time t=0.260000
# 2019-06-28 15:10:01,743 INFO CLAW: Solution 14 computed for time t=0.280000
# 2019-06-28 15:10:01,748 INFO CLAW: Solution 15 computed for time t=0.300000
# 2019-06-28 15:10:01,751 INFO CLAW: Solution 16 computed for time t=0.320000
# 2019-06-28 15:10:01,755 INFO CLAW: Solution 17 computed for time t=0.340000
# 2019-06-28 15:10:01,759 INFO CLAW: Solution 18 computed for time t=0.360000
# 2019-06-28 15:10:01,763 INFO CLAW: Solution 19 computed for time t=0.380000
# 2019-06-28 15:10:01,768 INFO CLAW: Solution 20 computed for time t=0.400000
# 2019-06-28 15:10:01,773 INFO CLAW: Solution 21 computed for time t=0.420000
# 2019-06-28 15:10:01,776 INFO CLAW: Solution 22 computed for time t=0.440000
# 2019-06-28 15:10:01,781 INFO CLAW: Solution 23 computed for time t=0.460000
# 2019-06-28 15:10:01,786 INFO CLAW: Solution 24 computed for time t=0.480000
# 2019-06-28 15:10:01,791 INFO CLAW: Solution 25 computed for time t=0.500000
# 2019-06-28 15:10:01,796 INFO CLAW: Solution 26 computed for time t=0.520000
# 2019-06-28 15:10:01,801 INFO CLAW: Solution 27 computed for time t=0.540000
# 2019-06-28 15:10:01,805 INFO CLAW: Solution 28 computed for time t=0.560000
# 2019-06-28 15:10:01,808 INFO CLAW: Solution 29 computed for time t=0.580000
# 2019-06-28 15:10:01,814 INFO CLAW: Solution 30 computed for time t=0.600000
# 2019-06-28 15:10:01,819 INFO CLAW: Solution 31 computed for time t=0.620000
# 2019-06-28 15:10:01,823 INFO CLAW: Solution 32 computed for time t=0.640000
# 2019-06-28 15:10:01,827 INFO CLAW: Solution 33 computed for time t=0.660000
# 2019-06-28 15:10:01,831 INFO CLAW: Solution 34 computed for time t=0.680000
# 2019-06-28 15:10:01,836 INFO CLAW: Solution 35 computed for time t=0.700000
# 2019-06-28 15:10:01,840 INFO CLAW: Solution 36 computed for time t=0.720000
# 2019-06-28 15:10:01,844 INFO CLAW: Solution 37 computed for time t=0.740000
# 2019-06-28 15:10:01,848 INFO CLAW: Solution 38 computed for time t=0.760000
# 2019-06-28 15:10:01,852 INFO CLAW: Solution 39 computed for time t=0.780000
# 2019-06-28 15:10:01,856 INFO CLAW: Solution 40 computed for time t=0.800000
# 2019-06-28 15:10:01,860 INFO CLAW: Solution 41 computed for time t=0.820000
# 2019-06-28 15:10:01,864 INFO CLAW: Solution 42 computed for time t=0.840000
# 2019-06-28 15:10:01,868 INFO CLAW: Solution 43 computed for time t=0.860000
# 2019-06-28 15:10:01,873 INFO CLAW: Solution 44 computed for time t=0.880000
# 2019-06-28 15:10:01,876 INFO CLAW: Solution 45 computed for time t=0.900000
# 2019-06-28 15:10:01,881 INFO CLAW: Solution 46 computed for time t=0.920000
# 2019-06-28 15:10:01,884 INFO CLAW: Solution 47 computed for time t=0.940000
# 2019-06-28 15:10:01,889 INFO CLAW: Solution 48 computed for time t=0.960000
# 2019-06-28 15:10:01,893 INFO CLAW: Solution 49 computed for time t=0.980000
# 2019-06-28 15:10:01,897 INFO CLAW: Solution 50 computed for time t=1.000000

# %% [markdown]
# We can plot the solution at any of our output times by specifying the frame:

# %%
pressure = claw.frames[50].q[0,:]
plt.plot(x,pressure,'-o')

# %% [markdown]
# Or, if you prefer, we can watch an animated version.

# %%
from matplotlib import animation
from clawpack.visclaw.JSAnimation import IPython_display

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, 1), ylim=(-0.2, 1.2))

frame = claw.frames[0]
pressure = frame.q[0,:]
line, = ax.plot([], [], lw=2)

def fplot(frame_number):
    frame = claw.frames[frame_number]
    pressure = frame.q[0,:]
    line.set_data(x,pressure)
    return line,

animation.FuncAnimation(fig, fplot, frames=len(claw.frames), interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, frame_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.frame_id = frame_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#     document.getElementById(this.frame_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgeefcb7ce3bd67b92" style="width:Nonepx">
#     <br>
#     <input id="_anim_slidereefcb7ce3bd67b92" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animeefcb7ce3bd67b92.set_frame(parseInt(this.value));"></input>
#     <br>
#
#     <button onclick="animeefcb7ce3bd67b92.slower()">&#8211;</button>
#     <button onclick="animeefcb7ce3bd67b92.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animeefcb7ce3bd67b92.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animeefcb7ce3bd67b92.faster()">+</button>
#   <form action="#n" name="_anim_loop_selecteefcb7ce3bd67b92" class="anim_control">
#
#     <input id="_frame_noeefcb7ce3bd67b92" type="textbox" size="1" onchange="animeefcb7ce3bd67b92.set_frame(parseInt(this.value));" onpaste="this.onchange();" oninput="this.onchange();"></input>
#
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
#
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgeefcb7ce3bd67b92";
#     var slider_id = "_anim_slidereefcb7ce3bd67b92";
#     var frame_id = "_frame_noeefcb7ce3bd67b92"
#     var loop_select_id = "_anim_loop_selecteefcb7ce3bd67b92";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64
